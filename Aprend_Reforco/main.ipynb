# %%
import gymnasium as gym

env = gym.make('Taxi-v3', render_mode='rgb_array')

# %%
env.reset()
# Out:
# (81, {'prob': 1.0, 'action_mask': array([1, 0, 0, 1, 0, 0], dtype=int8)})

# %%
env.render()
# Out:
# array([[[110, 109, 106],
#         [110, 109, 106],
#         [124, 122, 122],
#         ...,
#         [108, 111, 109],
#         [108, 111, 109],
#         [118, 119, 119]],
#
#        [[110, 109, 106],
#         [110, 109, 106],
#         [124, 122, 122],
#         ...,
#         [108, 111, 109],
#         [108, 111, 109],
#         [118, 119, 119]],
#
#        [[114, 116, 115],
#         [114, 116, 115],
#         [126, 127, 126],
#         ...,
#         [112, 113, 111],
#         [112, 113, 111],
#         [118, 117, 115]],
#
#        ...,
#
#        [[116, 115, 116],
#         [116, 115, 116],
#         [106, 107, 108],
#         ...,
#         [113, 115, 114],
#         [113, 115, 114],
#         [117, 114, 117]],
#
#        [[116, 115, 116],
#         [116, 115, 116],
#         [106, 107, 108],
#         ...,
#         [113, 115, 114],
#         [113, 115, 114],
#         [117, 114, 117]],
#
#        [[115, 112, 112],
#         [115, 112, 112],
#         [119, 119, 117],
# ...

# %%
import matplotlib.pyplot as plt

# %%
env.step(3) ## Fazendo um passo para o norte
plt.imshow(env.render())
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(549.5), np.float64(349.5), np.float64(-0.5))

# %%
import numpy as np

# %%
[env.observation_space.n, env.action_space.n]
# Out:
# [np.int64(500), np.int64(6)]
